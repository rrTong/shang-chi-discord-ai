# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive/discord-ai')

# %%
# !ls
# Out:
# kaggle.json
# model_train_upload_workflow.ipynb
# parse_script.ipynb
# shang-chi-and-the-legend-of-the-ten-rings.txt

# %%
import re
import pandas as pd

# %%
pattern = r'(^[a-zA-Z\s-]+):(.+)'

# %%
data = {
    'name': [],
    'line': []
}

# %%
with open('shang-chi-and-the-legend-of-the-ten-rings.txt', 'rt') as file:
  for line in file.readlines():
    match = re.findall(pattern, line)
    if match:
      name, line = match[0]
      data['name'].append(name)
      data['line'].append(line)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   name                           line
# 0   LI                 十环的传说已经流传了上千年。
# 1   LI                    不论这个故事如何演变。
# 2   LI                 它的主人公永远都是同一个人。
# 3   LI   有人说他的十环是火山口里捡来的 还有人说是墓穴里盗来的。
# 4   LI      它们给了他神一般的力量，也赋予了他长生不老的魔法。

# %%
sum(df['name'] == 'SHANG-CHI')
# Out:
# 168

# %%
len(df)
# Out:
# 1053

# %%
df.to_csv('shang-chi-and-the-legend-of-the-ten-rings.csv', index=False)
